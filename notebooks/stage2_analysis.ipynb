# %% [markdown]
# # Stage 2 - Bayesian Optimization Capstone
#
# """
# Objective:
# Analyze query behavior across rounds and understand exploration vs exploitation.
#
# We currently have:
# - Round 1 queries
# - Round 2 queries
# - Preparing Round 3
#
# Goal:
# Identify patterns and improve strategy.
# """

# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %%
BASE = Path("..")
DATA_DIR = BASE / "data"
